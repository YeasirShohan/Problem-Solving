# %% [markdown]
# # **Assignment: 05**
#
# ##**Topic: Introduction to list, Working with list, If statements**
#
# **Source: Python Crash Cource**
#
# **Submitted by: Yeasir Arafat Shohan**
#
# **Discord ID: 0781**

# %% [markdown]
# #**Introduction to list**

# %% [markdown]
# #**Examples**

# %%
# example of a list
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles)
# Out:
# ['trek', 'cannondale', 'redline', 'specialized']

# %%
# Accessing Elements in a List
bicycles = ['trek', 'cannondale', 'redline', 'specialized'] #pull out the first bicycle in the list bicycles
print(bicycles[0])
# Out:
# trek

# %%
#we can format the element 'trek' more neatly by using the title() method
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles[0].title())
# Out:
# Trek

# %%
#following asks for the bicycles
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles[1])
print(bicycles[3])
# Out:
# cannondale
# specialized

# %%
# the item at index -1, Python always returns the last item in the list
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles[-1])
# Out:
# specialized

# %%
#the first bicycle from the list and composing a message using that value
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
message = "My first bicycle was a " + bicycles[0].title() + "."
print(message)
# Out:
# My first bicycle was a Trek.

# %%
# we change the value of this first item
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
motorcycles[0] = 'ducati'
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['ducati', 'yamaha', 'suzuki']

# %%
# add the new element 'ducati' to the end of the list
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
motorcycles.append('ducati')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha', 'suzuki', 'ducati']

# %%
# add the elements 'honda', 'yamaha', and 'suzuki' to the list
motorcycles = []
motorcycles.append('honda')
motorcycles.append('yamaha')
motorcycles.append('suzuki')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']

# %%
# the new element and the value of the new item
motorcycles = ['honda', 'yamaha', 'suzuki']
motorcycles.insert(0, 'ducati')
print(motorcycles)
# Out:
# ['ducati', 'honda', 'yamaha', 'suzuki']

# %%
# Removing an Item Using the del Statement
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
del motorcycles[0]
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['yamaha', 'suzuki']

# %%
# to remove the second item, 'yamaha', in the list
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
del motorcycles[1]
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'suzuki']

# %%
# Let’s pop a motorcycle from the list of motorcycles
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
popped_motorcycle = motorcycles.pop()
print(motorcycles)
print(popped_motorcycle)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha']
# suzuki

# %%
# the last motorcycle we bought
motorcycles = ['honda', 'yamaha', 'suzuki']
last_owned = motorcycles.pop()
print("The last motorcycle I owned was a " + last_owned.title() + ".")
# Out:
# The last motorcycle I owned was a Suzuki.

# %%
# remove the value 'ducati' and print a reason for removing it from the list
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)
too_expensive = 'ducati'
motorcycles.remove(too_expensive)
print(motorcycles)
print("\nA " + too_expensive.title() + " is too expensive for me.")
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']
#
# A Ducati is too expensive for me.

# %%
#assume that all the values in the list are lowercase
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort()
print(cars)
# Out:
# ['audi', 'bmw', 'subaru', 'toyota']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort(reverse=True)
print(cars)
# Out:
# ['toyota', 'subaru', 'bmw', 'audi']

# %%
#  try this function on the list of cars
cars = ['bmw', 'audi', 'toyota', 'subaru']
print("Here is the original list:")
print(cars)
print("\nHere is the sorted list:")
print(sorted(cars))
print("\nHere is the original list again:")
print(cars)
# Out:
# Here is the original list:
# ['bmw', 'audi', 'toyota', 'subaru']
#
# Here is the sorted list:
# ['audi', 'bmw', 'subaru', 'toyota']
#
# Here is the original list again:
# ['bmw', 'audi', 'toyota', 'subaru']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
print(cars)
cars.reverse()
print(cars)
# Out:
# ['bmw', 'audi', 'toyota', 'subaru']
# ['subaru', 'toyota', 'audi', 'bmw']

# %%
#Avoiding Index Errors When Working with Lists
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles[3])

# %%
#to access the last item in a list you use the index -1
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles[-1])
# Out:
# suzuki

# %%
#error call
motorcycles = []
print(motorcycles[-1])

# %% [markdown]
# #**Exersices**

# %% [markdown]
# 01: Store the names of a few of your friends in a list called names. Print
# each persons name by accessing each element in the list, one at a time.

# %%
names = ['Bishal', 'Somudro', 'abir']

for name in names:
    print(name)
# Out:
# Bishal
# Somudro
# abir

# %% [markdown]
# 02: Start with the list you used in Exercise 1, but instead of just
# printing each person’s name, print a message to them. The text of each message should be the same, but each message should be personalized with the
# person’s name.

# %%
names = ['Bishal', 'Somudro', 'abir']

for name in names:
    print("Hello, " + name + "! How are you?")
# Out:
# Hello, Bishal! How are you?
# Hello, Somudro! How are you?
# Hello, abir! How are you?

# %% [markdown]
# 03: Think of your favorite mode of transportation, such as a
# motorcycle or a car, and make a list that stores several examples. Use your list
# to print a series of statements about these items, such as “I would like to own a
# Honda motorcycle.”

# %%
transportation = ['suzuki motorcycle', 'yamaha motorcycle', 'honda motorcycle', 'Royal enfiled']

for item in transportation:
    print("I want to own a", item + ".")
# Out:
# I want to own a suzuki motorcycle.
# I want to own a yamaha motorcycle.
# I want to own a honda motorcycle.
# I want to own a Royal enfiled.

# %% [markdown]
# 04: If you could invite anyone, living or deceased, to dinner, who
# would you invite? Make a list that includes at least three people you’d like to
# invite to dinner. Then use your list to print a message to each person, inviting
# them to dinner.

# %%
people = ['Bishal', 'Somudro', 'Abir']

for guest in people:
    print("Hello", guest + ", You are mostly invited in my dinner!")
# Out:
# Hello Bishal, You are mostly invited in my dinner!
# Hello Somudro, You are mostly invited in my dinner!
# Hello Abir, You are mostly invited in my dinner!

# %% [markdown]
# 05: You just heard that one of your guests can’t make the
# dinner, so you need to send out a new set of invitations. You’ll have to think of
# someone else to invite.
# •	 Start with your program from Exercise 4. Add a print statement at the
# end of your program stating the name of the guest who can’t make it.
# •	 Modify your list, replacing the name of the guest who can’t make it with
# the name of the new person you are inviting.
# •	 Print a second set of invitation messages, one for each person who is still
# in your list.

# %%
people = ['Bishal', 'Somudro', 'Abir']

for guest in people:
    print("Hello", guest + ", You are mostly invited in my dinner!")

print("Original Guest List:")

unavailable = people[2]
print(f"Oh, {unavailable} Thanks for not coming!")

people[2] = 'Polash' 

print("Updated Guest List:")

for guest in people:
    print("Hello", guest + ", You are mostly invited in my dinner!")
# Out:
# Hello Bishal, You are mostly invited in my dinner!
# Hello Somudro, You are mostly invited in my dinner!
# Hello Abir, You are mostly invited in my dinner!
# Original Guest List:
# Oh, Abir Thanks for not coming!
# Updated Guest List:
# Hello Bishal, You are mostly invited in my dinner!
# Hello Somudro, You are mostly invited in my dinner!
# Hello Polash, You are mostly invited in my dinner!

# %% [markdown]
# 06: You just found a bigger dinner table, so now more space is
# available. Think of three more guests to invite to dinner.
# •	 Start with your program from Exercise 4 or Exercise 5. Add a print
# statement to the end of your program informing people that you found a
# bigger dinner table.
# •	 Use insert() to add one new guest to the beginning of your list.
# •	 Use insert() to add one new guest to the middle of your list.
# •	 Use append() to add one new guest to the end of your list.
# •	 Print a new set of invitation messages, one for each person in your list.

# %%
people = ['Bishal', 'Somudro', 'Abir']

for guest in people:
    print("Hello", guest + ", You are mostly invited in my dinner!")


print("Original Guest List:")

unavailable = people[2]
print(f"Oh, {unavailable} Thanks for not coming!")

people[2] = 'Polash' 

print("Updated Guest List:")

for guest in people:
    print("Hello", guest + ", You are mostly invited in my dinner!")

print("Regret")
for regrets in people[2]:
    print("Hello", regrets + ", Thanks for not coming, my money was saved!")


print("Good news! I found a bigger dinner table.")


people.insert(0, 'shawon')  
people.insert(len(people) // 2, 'Anonto') 
people.append('Siam')  

print("Final Guest List:")
for guest in people:
    
    print(guest)

# %% [markdown]
# 07: You just found out that your new dinner table won’t
# arrive in time for the dinner, and you have space for only two guests.
# •	 Start with your program from Exercise 6. Add a new line that prints a
# message saying that you can invite only two people for dinner.
# •	 Use pop() to remove guests from your list one at a time until only two
# names remain in your list. Each time you pop a name from your list, print
# a message to that person letting them know you’re sorry you can’t invite
# them to dinner.
# •	 Print a message to each of the two people still on your list, letting them
# know they’re still invited.
# •	 Use del to remove the last two names from your list, so you have an empty
# list. Print your list to make sure you actually have an empty list at the end
# of your program.

# %%
people = ['Bishal', 'Somudro', 'Abir']

for guest in people:
    print("Hello", guest + ", You are mostly invited in my dinner!")


print("Original Guest List:")

unavailable = people[2]
print(f"Oh, {unavailable} Thanks for not coming!")

people[2] = 'Polash' 

print("Updated Guest List:")

for guest in people:
    print("Hello", guest + ", You are mostly invited in my dinner!")

print("Regret")
for regrets in people[2]:
    print("Hello", regrets + ", Thanks for not coming, my money was saved!")


print("Good news! I found a bigger dinner table.")


people.insert(0, 'shawon')  
people.insert(len(people) // 2, 'Anonto') 
people.append('Siam')  

print("Final Guest List:")
for guest in people:
    
    print(guest)

print("Sorry, party dismis!")

while len(people) > 2:
    removed_guest = people.pop()
    print(f"Sorry, {removed_guest}, you people's are out")


for guest in people:
    print(f"{guest}, you people are invited but in condition!")

del people[:]
print("People List:", people)

# %% [markdown]
# 08: Think of at least five places in the world you’d like to
# visit.
# •	 Store the locations in a list. Make sure the list is not in alphabetical order.
# •	 Print your list in its original order. Don’t worry about printing the list neatly,
# just print it as a raw Python list.
# •	 Use sorted() to print your list in alphabetical order without modifying the
# actual list.
# •	 Show that your list is still in its original order by printing it.
# •	 Use sorted() to print your list in reverse alphabetical order without changing the order of the original list.
# •	 Show that your list is still in its original order by printing it again.
# •	 Use reverse() to change the order of your list. Print the list to show that its
# order has changed.
# •	 Use reverse() to change the order of your list again. Print the list to show
# it’s back to its original order.
# •	 Use sort() to change your list so it’s stored in alphabetical order. Print the
# list to show that its order has been changed.
# •	 Use sort() to change your list so it’s stored in reverse alphabetical order.
# Print the list to show that its order has changed.

# %%
places = ['UAS', 'Australia', 'swezerland', 'India', 'Canada']

print("Original List:", places)

print("Alphabetical Order:", sorted(places))

print("Original List:", places)

print("Reverse Alphabetical Order:", sorted(places, reverse=True))

print("Original List:", places)

places.reverse()

print("Reversed Order:", places)

places.reverse()

print("Original List:", places)

places.sort()

print("Alphabetical Order:", places)

places.sort(reverse=True)

print("Reverse Alphabetical Order:", places)
# Out:
# Original List: ['UAS', 'Australia', 'swezerland', 'India', 'Canada']
# Alphabetical Order: ['Australia', 'Canada', 'India', 'UAS', 'swezerland']
# Original List: ['UAS', 'Australia', 'swezerland', 'India', 'Canada']
# Reverse Alphabetical Order: ['swezerland', 'UAS', 'India', 'Canada', 'Australia']
# Original List: ['UAS', 'Australia', 'swezerland', 'India', 'Canada']
# Reversed Order: ['Canada', 'India', 'swezerland', 'Australia', 'UAS']
# Original List: ['UAS', 'Australia', 'swezerland', 'India', 'Canada']
# Alphabetical Order: ['Australia', 'Canada', 'India', 'UAS', 'swezerland']
# Reverse Alphabetical Order: ['swezerland', 'UAS', 'India', 'Canada', 'Australia']

# %% [markdown]
# 09: Working with one of the programs from Exercises 4
# through 7, use len() to print a message indicating the number
# of people you are inviting to dinner.

# %%
people = ['Bishal', 'Somudro', 'Abir']

for guest in people:
    print("Hello", guest + ", You are mostly invited in my dinner!")


print("Original Guest List:")

unavailable = people[2]
print(f"Oh, {unavailable} Thanks for not coming!")

people[2] = 'Polash' 

print("Updated Guest List:")

for guest in people:
    print("Hello", guest + ", You are mostly invited in my dinner!")

print("Regret")
for regrets in people[2]:
    print("Hello", regrets + ", Thanks for not coming, my money was saved!")


print("Good news! I found a bigger dinner table.")


people.insert(0, 'shawon')  
people.insert(len(people) // 2, 'Anonto') 
people.append('Siam')  

print("Final Guest List:")
for guest in people:
    
    print(guest)

print("Sorry, party dismis!")

while len(people) > 2:
    removed_guest = people.pop()
    print(f"Sorry, {removed_guest}, you people's are out")


for guest in people:
    print(f"{guest}, you people are invited but in condition!")

del people[:]
print("People List:", people)
num_invited = len(people)
print(f"people invited to dinner: {num_invited}")

# %% [markdown]
# 10: Think of something you could store in a list. For example,
# you could make a list of mountains, rivers, countries, cities, languages, or anything else you’d like. Write a program that creates a list containing these items
# and then uses each function introduced in this chapter at least once.

# %%
landmarks = ['Eiffel Tower','Colosseum','Pyramids of Giza','Taj Mahal', 'Machu Picchu' 'Statue of Liberty']

landmarks.append('Great Wall of China')
print("Appended List:", landmarks)
landmarks.insert(2, 'Machu Picchu' )
print("Inserted List:", landmarks)
landmarks.remove('Machu Picchu')
print("Removed List:", landmarks)
popped_landmark = landmarks.pop()
print("Popped Landmark:", popped_landmark)
print("Remaining List:", landmarks)
landmarks.sort()
print("Sorted List:", landmarks)
landmarks.reverse()
print("Reversed List:", landmarks)
num_landmarks = len(landmarks)
print("Number of Landmarks:", num_landmarks)
index = landmarks.index('Taj Mahal')
print("Index of Taj Mahal:", index)
count = landmarks.count('Eiffel Tower')
print("Count of Eiffel Tower:", count)
landmarks.clear()
print("Cleared List:", landmarks)
# Out:
# Appended List: ['Eiffel Tower', 'Colosseum', 'Pyramids of Giza', 'Taj Mahal', 'Machu PicchuStatue of Liberty', 'Great Wall of China']
# Inserted List: ['Eiffel Tower', 'Colosseum', 'Machu Picchu', 'Pyramids of Giza', 'Taj Mahal', 'Machu PicchuStatue of Liberty', 'Great Wall of China']
# Removed List: ['Eiffel Tower', 'Colosseum', 'Pyramids of Giza', 'Taj Mahal', 'Machu PicchuStatue of Liberty', 'Great Wall of China']
# Popped Landmark: Great Wall of China
# Remaining List: ['Eiffel Tower', 'Colosseum', 'Pyramids of Giza', 'Taj Mahal', 'Machu PicchuStatue of Liberty']
# Sorted List: ['Colosseum', 'Eiffel Tower', 'Machu PicchuStatue of Liberty', 'Pyramids of Giza', 'Taj Mahal']
# Reversed List: ['Taj Mahal', 'Pyramids of Giza', 'Machu PicchuStatue of Liberty', 'Eiffel Tower', 'Colosseum']
# Number of Landmarks: 5
# Index of Taj Mahal: 0
# Count of Eiffel Tower: 1
# Cleared List: []

# %% [markdown]
# 11: If you haven’t received an index error in one of your
# programs yet, try to make one happen. Change an index in one of your programs to produce an index error. Make sure you correct the error before closing the program.

# %%
landmarks = ['Eiffel Tower','Colosseum','Pyramids of Giza','Taj Mahal', 'Machu Picchu','Statue of Liberty']

if len(landmarks) > 10:
    index = 2
    print("Corrected Index:", landmarks[index])
else:
    print("Index out of range.")
# Out:
# Index out of range.

# %% [markdown]
# #**Working with list**

# %% [markdown]
# ##**Examples**

# %%
#use a for loop to print out each name in a list of magicians

magicians = ['alice', 'david', 'carolina']
for magician in magicians:
    print(magician)
# Out:
# alice
# david
# carolina

# %%
#telling them that they performed a great trick
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
    print(magician.title() + ", that was a great trick!")
# Out:
# Alice, that was a great trick!
# David, that was a great trick!
# Carolina, that was a great trick!

# %%
#add a second line to our message
magicians = ['shohan','sam','bishal']
for magician in magicians:
 print(magician.title() + ", that was a great trick!")
print("I can't wait to see your next trick, " + magician.title() + ".\n")
# Out:
# Shohan, that was a great trick!
# Sam, that was a great trick!
# Bishal, that was a great trick!
# I can't wait to see your next trick, Bishal.

# %%
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
   print(magician)
# Out:
# alice
# david
# carolina

# %%
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
  print(magician.title() + ", that was a great trick!")
print("I can't wait to see your next trick, " + magician.title() + ".\n")
# Out:
# Alice, that was a great trick!
# David, that was a great trick!
# Carolina, that was a great trick!
# I can't wait to see your next trick, Carolina.

# %%
# the line that thanked the magicians as a group for putting on a good show
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
 print(magician.title() + ", that was a great trick!")
 print("I can't wait to see your next trick, " + magician.title() + ".\n")

print("Thank you everyone, that was a great magic show!")

# %%
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
    print(magician)
# Out:
# alice
# david
# carolina

# %%
# Slicing a List
players = ['charles', 'martina', 'michael', 'florence', 'eli']
print(players[0:3])
# Out:
# ['charles', 'martina', 'michael']

# %%
'''the second, third, and fourth items in a list, you would start the slice at index 1 and
end at index 4: '''

players = ['charles', 'martina', 'michael', 'florence', 'eli']
print(players[1:4])

# %%
# Looping Through a Slice
players = ['charles', 'martina', 'michael', 'florence', 'eli']
print("Here are the first three players on my team:")
for player in players[:3]:
   print(player.title())
# Out:
# Here are the first three players on my team:
# Charles
# Martina
# Michael

# %%
''' imagine we have a list of our favorite foods and want to
make a separate list of foods that a friend likes. This friend likes everything
in our list so far, so we can create their list by copying ours'''

my_foods = ['pizza', 'falafel', 'carrot cake']
friend_foods = my_foods[:]
print("My favorite foods are:")
print(my_foods)
print("\nMy friend's favorite foods are:")
print(friend_foods)
# Out:
# My favorite foods are:
# ['pizza', 'falafel', 'carrot cake']
#
# My friend's favorite foods are:
# ['pizza', 'falafel', 'carrot cake']

# %% [markdown]
# ##**Excercise**

# %% [markdown]
# 01: Think of at least three kinds of your favorite pizza. Store these
# pizza names in a list, and then use a for loop to print the name of each pizza.
# •	 Modify your for loop to print a sentence using the name of the pizza
# instead of printing just the name of the pizza. For each pizza you should
# have one line of output containing a simple statement like I like pepperoni
# pizza.
# •	 Add a line at the end of your program, outside the for loop, that states
# how much you like pizza. The output should consist of three or more lines
# about the kinds of pizza you like and then an additional sentence, such as
# I really love pizza!

# %%
pizzas = ["Hawaiian", "Pepperoni", "Margherita"]

print("Pizza :")
for pizza in pizzas:
    print(pizza)
print("\nPizza statements:")
for pizza in pizzas:
    print("I like", pizza, "pizza.")
print("\nI really love pizza with Python!")
# Out:
# Pizza :
# Hawaiian
# Pepperoni
# Margherita
#
# Pizza statements:
# I like Hawaiian pizza.
# I like Pepperoni pizza.
# I like Margherita pizza.
#
# I really love pizza with Python!

# %% [markdown]
#  02: Think of at least three different animals that have a common characteristic. Store the names of these animals in a list, and then use a for loop to
# print out the name of each animal.
# •	 Modify your program to print a statement about each animal, such as
# A dog would make a great pet.
# •	 Add a line at the end of your program stating what these animals have in
# common. You could print a sentence such as Any of these animals would
# make a great pet!

# %%
animals = ["Rabbit","Dog", "Cat"]
print("Animal names:")
for animal in animals:
    print(animal)
print("\nAnimal statements:")
for animal in animals:
    print("A", animal.lower(), "would make a great pet.")
print("\nAny of these animals would make a great pet!")

# %% [markdown]
# 03: Use a for loop to print the numbers from 1 to 20,
# inclusive.

# %%
for num in range(1, 21):
    print(num)

# %% [markdown]
# 04: Make a list of the numbers from one to one million, and then
# use a for loop to print the numbers. (If the output is taking too long, stop it by
# pressing ctrl-C or by closing the output window.)

# %%
num = list(range(1, 1000000))
for number in num[:100]:
    print(number)

# %% [markdown]
# 05:Make a list of the numbers from one to one million,
# and then use min() and max() to make sure your list actually starts at one and
# ends at one million. Also, use the sum() function to see how quickly Python can
# add a million numbers.

# %%
numbers = list(range(1, 1000000))
print("Minimum value:", min(numbers))
print("Maximum value:", max(numbers))
print("Sum of the numbers:", sum(numbers))

# %% [markdown]
# 06: Use the third argument of the range() function to make a list
# of the odd numbers from 1 to 20. Use a for loop to print each number

# %%
numbers = list(range(1, 20, 2))
for number in numbers:
    print(number)

# %% [markdown]
# 07: Make a list of the multiples of 3 from 3 to 30. Use a for loop to
# print the numbers in your list.

# %%
multiples_of_three = list(range(3, 30, 3))
for number in multiples_of_three:
    print(number)

# %% [markdown]
# 08: A number raised to the third power is called a cube. For example,
# the cube of 2 is written as 2**3 in Python. Make a list of the first 10 cubes (that
# is, the cube of each integer from 1 through 10), and use a for loop to print out
# the value of each cube.

# %%
cubes = []
for number in range(1, 10):
    cube = number ** 3
    cubes.append(cube)
for cube in cubes:
    print(cube)

# %% [markdown]
# 09: Use a list comprehension to generate a list of the
# first 10 cubes.

# %%
cubes = [number ** 3 for number in range(1, 10)]
for cube in cubes:
    print(cube)

# %% [markdown]
# 10:Using one of the programs you wrote in this chapter, add several
# lines to the end of the program that do the following:
# •	 Print the message, The first three items in the list are:. Then use a slice to
# print the first three items from that program’s list.
# •	 Print the message, Three items from the middle of the list are:. Use a slice
# to print three items from the middle of the list.
# •	 Print the message, The last three items in the list are:. Use a slice to print
# the last three items in the list.

# %%
cubes = [number ** 3 for number in range(1, 10)]
for cube in cubes:
    print(cube)
print("The first three items in the list are:", cubes[:3])
mid_start = len(cubes) // 2 - 1
mid_end = mid_start + 3
print("Three items from the middle of the list are:", cubes[mid_start:mid_end])
print("The last three items in the list are:", cubes[-3:])

# %% [markdown]
# 11: Start with your program from Exercise 1. Make a copy of the list of pizzas, and call it friend_pizzas.
# Then, do the following:
# •	 Add a new pizza to the original list.
# •	 Add a different pizza to the list friend_pizzas.
# •	 Prove that you have two separate lists. Print the message, My favorite
# pizzas are:, and then use a for loop to print the first list. Print the message,
# My friend’s favorite pizzas are:, and then use a for loop to print the second list. Make sure each new pizza is stored in the appropriate list.

# %%
pizzas = ["Hawaiian", "Pepperoni", "Margherita"]
friend_pizzas = pizzas.copy()
pizzas.append("Vegetarian")
friend_pizzas.append("BBQ Chicken")
print("My favorite pizzas are:")
for pizza in pizzas:
    print(pizza)
print("\nMy friend's favorite pizzas are:")
for pizza in friend_pizzas:
    print(pizza)
# Out:
# My favorite pizzas are:
# Hawaiian
# Pepperoni
# Margherita
# Vegetarian
#
# My friend's favorite pizzas are:
# Hawaiian
# Pepperoni
# Margherita
# BBQ Chicken

# %% [markdown]
# 12:All versions of foods.py in this section have avoided using
# for loops when printing to save space. Choose a version of foods.py, and
# write two for loops to print each list of foods.

# %%
foods = ["Pizza", "Burger", "Sushi", "Pasta", "Ice Cream"]
friend_foods = ["Tacos", "Steak", "Salad", "Chicken Wings", "Chocolate Cake"]
print("My favorite foods are:")
for food in foods:
    print(food)
print("\nMy friend's favorite foods are:")
for food in friend_foods:
    print(food)
# Out:
# My favorite foods are:
# Pizza
# Burger
# Sushi
# Pasta
# Ice Cream
#
# My friend's favorite foods are:
# Tacos
# Steak
# Salad
# Chicken Wings
# Chocolate Cake

# %% [markdown]
# 13:A buffet-style restaurant offers only five basic foods. Think of five
# simple foods, and store them in a tuple.
# •	 Use a for loop to print each food the restaurant offers.
# •	 Try to modify one of the items, and make sure that Python rejects the
# change.
# •	 The restaurant changes its menu, replacing two of the items with different
# foods. Add a block of code that rewrites the tuple, and then use a for
# loop to print each of the items on the revised menu.

# %%
menu = ("Burger", "Pizza", "Sushi", "Pasta", "Ice Cream")
print("Original Menu:")
for food in menu:
    print(food)
menu = ("Hot Dog", "Tacos", "Sushi", "Fried Rice", "Cake")
print("\nRevised Menu:")
for food in menu:
    print(food)

# %% [markdown]
# 15:Choose three of the programs you’ve written in this chapter
# and modify each one to comply with PEP 8:
# •	 Use four spaces for each indentation level. Set your text editor to insert
# four spaces every time you press tab, if you haven’t already done so (see
# Appendix B for instructions on how to do this).
# •	 Use less than 80 characters on each line, and set your editor to show a
# vertical guideline at the 80th character position.
# •	 Don’t use blank lines excessively in your program files.

# %%
cubes = []
for number in range(1, 10):
    cube = number ** 3
    cubes.append(cube)
for cube in cubes:
    print(cube)

#2nd
odd_numbers = []
for number in range(1, 21, 2):
    odd_numbers.append(number)
for number in odd_numbers:
    print(number)

# 3rd
multiples_of_3 = []
for number in range(3, 31, 3):
    multiples_of_3.append(number)
for number in multiples_of_3:
    print(number)

# %% [markdown]
# #**If statements**

# %% [markdown]
# ##**Examples**

# %%
# the value is 'bmw', it’s printed in uppercase instead of title case

cars = ['audi', 'bmw', 'subaru', 'toyota']
for car in cars:
    if car == 'bmw':
        print(car.upper())
    else:
        print(car.title())
# Out:
# Audi
# BMW
# Subaru
# Toyota

# %% [markdown]
# ##**Excercise**

# %% [markdown]
# 01: Write a series of conditional tests. Print a statement
# describing each test and your prediction for the results of each test. Your code
# should look something like this:
# car = 'subaru'
# print("Is car == 'subaru'? I predict True.")
# print(car == 'subaru')
# print("\nIs car == 'audi'? I predict False.")
# print(car == 'audi')
# •	 Look closely at your results, and make sure you understand why each line
# evaluates to True or False.
# •	 Create at least 10 tests. Have at least 5 tests evaluate to True and another
# 5 tests evaluate to False

# %%
car = 'subaru'

print("Is car == 'subaru'? I predict True.")
print(car == 'subaru')

print("\nIs car == 'audi'? I predict False.")
print(car == 'audi')

print("\nIs car == 'Subaru'? I predict False.")
print(car == 'Subaru')

print("\nIs car == 'subaru' or car == 'Subaru'? I predict True.")
print(car == 'subaru' or car == 'Subaru')

print("\nIs car == 'Subaru' and car == 'subaru'? I predict False.")
print(car == 'Subaru' and car == 'subaru')

print("\nIs car == 'subaru' or car == 'audi'? I predict True.")
print(car == 'subaru' or car == 'audi')

print("\nIs car == 'audi' and car == 'subaru'? I predict False.")
print(car == 'audi' and car == 'subaru')

print("\nIs car != 'ford'? I predict True.")
print(car != 'ford')

print("\nIs car.startswith('su')? I predict True.")
print(car.startswith('su'))

print("\nIs len(car) == 6? I predict False.")
print(len(car) == 6)

# %% [markdown]
# 02: Imagine an alien was just shot down in a game. Create a
# variable called alien_color and assign it a value of 'green', 'yellow', or 'red'.
# •	 Write an if statement to test whether the alien’s color is green. If it is, print
# a message that the player just earned 5 points.
# •	 Write one version of this program that passes the if test and another that
# fails. (The version that fails will have no output.)

# %%
alien_color = 'green'

if alien_color == 'green':
    print("Congratulations! You just earned 5 points!")
# Out:
# Congratulations! You just earned 5 points!

# %% [markdown]
# 04: Choose a color for an alien as you did in Exercise 5-3, and
# write an if-else chain.
# •	 If the alien’s color is green, print a statement that the player just earned
# 5 points for shooting the alien.
# •	 If the alien’s color isn’t green, print a statement that the player just earned
# 10 points.
# •	 Write one version of this program that runs the if block and another that
# runs the else block.

# %%
alien_color = 'orange'

if alien_color == 'green':
    print("Congratulations! You just earned 5 points for shooting the green alien.")
else:
    print("Congratulations! You just earned 10 points.")
# Out:
# Congratulations! You just earned 10 points.

# %% [markdown]
# 05: Turn your if-else chain from Exercise 5-4 into an if-elifelse chain.
# •	 If the alien is green, print a message that the player earned 5 points.
# •	 If the alien is yellow, print a message that the player earned 10 points.
# •	 If the alien is red, print a message that the player earned 15 points.
# •	 Write three versions of this program, making sure each message is printed
# for the appropriate color alien.

# %%
alien_color = 'green'

if alien_color == 'green':
    print("Congratulations! You just earned 5 points.")
elif alien_color == 'yellow':
    print("Congratulations! You just earned 10 points.")
else:
    print("Congratulations! You just earned 15 points.")
# Out:
# Congratulations! You just earned 5 points.

# %% [markdown]
# 06: Write an if-elif-else chain that determines a person’s
# stage of life. Set a value for the variable age, and then:
# •	 If the person is less than 2 years old, print a message that the person is
# a baby.
# •	 If the person is at least 2 years old but less than 4, print a message that
# the person is a toddler.
# •	 If the person is at least 4 years old but less than 13, print a message that
# the person is a kid.
# •	 If the person is at least 13 years old but less than 20, print a message that
# the person is a teenager.
# •	 If the person is at least 20 years old but less than 65, print a message that
# the person is an adult.
# •	 If the person is age 65 or older, print a message that the person is an
# elder.

# %%
age = 25

if age < 2:
    print("This person is a baby.")
elif age < 4:
    print("This person is a toddler.")
elif age < 13:
    print("This person is a kid.")
elif age < 20:
    print("This person is a teenager.")
elif age < 65:
    print("This person is an adult.")
else:
    print("This person is an elder.")

# %% [markdown]
# 07:: Make a list of your favorite fruits, and then write a series of
# independent if statements that check for certain fruits in your list.
# •	 Make a list of your three favorite fruits and call it favorite_fruits.
# •	 Write five if statements. Each should check whether a certain kind of fruit
# is in your list. If the fruit is in your list, the if block should print a statement,
# such as You really like bananas!

# %%
favorite_fruits = ['jack_fruit','banana', 'mango',]

if 'jack_fruit' in favorite_fruits:
    print("You really like jack_fruit!")
if 'banana' in favorite_fruits:
    print("You really like banana!")
if 'orange' in favorite_fruits:
    print("You really like oranges!")
if 'mango' in favorite_fruits:
    print("You really like mangoe!")
if 'strawberry' in favorite_fruits:
    print("You really like strawberrie!")
# Out:
# You really like jack_fruit!
# You really like banana!
# You really like mangoe!

# %% [markdown]
# 08: Make a list of five or more usernames, including the name
# 'admin'. Imagine you are writing code that will print a greeting to each user
# after they log in to a website. Loop through the list, and print a greeting to
# each user:
# •	 If the username is 'admin', print a special greeting, such as Hello admin,
# would you like to see a status report?
# •	 Otherwise, print a generic greeting, such as Hello Eric, thank you for logging in again.

# %%
usernames = ['admin', 'Bishal', 'Somudro', 'Abir']

for username in usernames:
    if username == 'admin':
        print("Hello admin, would you like to see a status report?")
    else:
        print(f"Hello {username}, thank you for logging in again.")

# %% [markdown]
# 10: Do the following to create a program that simulates
# how websites ensure that everyone has a unique username.
# •	 Make a list of five or more usernames called current_users.
# •	 Make another list of five usernames called new_users. Make sure one or
# two of the new usernames are also in the current_users list.
# •	 Loop through the new_users list to see if each new username has already
# been used. If it has, print a message that the person will need to enter a
# new username. If a username has not been used, print a message saying
# that the username is available.
# •	 Make sure your comparison is case insensitive. If 'John' has been used,
# 'JOHN' should not be accepted.

# %%
users = ['Bishal', 'Somudro', 'Abir','shohan','anonto']
new_users = ['siam','Bishal','minar', 'Somudro','asif']

users_lower = [user.lower() for user in users]

for new_user in new_users:
    if new_user.lower() in users_lower:
        print(f"Sorry, the username '{new_user}' is already taken. Please enter a new username.")
    else:
        print(f"The username '{new_user}' is available.")
# Out:
# The username 'siam' is available.
# Sorry, the username 'Bishal' is already taken. Please enter a new username.
# The username 'minar' is available.
# Sorry, the username 'Somudro' is already taken. Please enter a new username.
# The username 'asif' is available.

# %% [markdown]
# 11: Ordinal numbers indicate their position in a list, such
# as 1st or 2nd. Most ordinal numbers end in th, except 1, 2, and 3.
# •	 Store the numbers 1 through 9 in a list.
# •	 Loop through the list.
# •	 Use an if-elif-else chain inside the loop to print the proper ordinal ending for each number. Your output should read "1st 2nd 3rd 4th 5th 6th
# 7th 8th 9th", and each result should be on a separate line.

# %%
numbers = list(range(1, 10))

for number in numbers:
    if number == 1:
        ordinal = '1st'
    elif number == 2:
        ordinal = '2nd'
    elif number == 3:
        ordinal = '3rd'
    else:
        ordinal = str(number) + 'th'
    
    print(ordinal)
# Out:
# 1st
# 2nd
# 3rd
# 4th
# 5th
# 6th
# 7th
# 8th
# 9th
