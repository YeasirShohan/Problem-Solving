# %% [markdown]
# # **Assignment : 01**
# ## **Yeasir Arafat Shohan**
# **Topic: Syntex, Comments, Variables, Data Types**
#
# **Discord ID: 0781**

# %% [markdown]
# **Exercise code**

# %% [markdown]
# 2-1. Simple Message

# %%
x = "This is a first Assingment"
print(x)
# Out:
# This is a first Assingment

# %% [markdown]
# 2-2. Simple Messages

# %%
x = "This is a first Assingment"
print(x)
#change value of variable
x = "This is a change value of variable"
print(x)
# Out:
# This is a first Assingment
# This is a change value of variable

# %% [markdown]
# 2-3. Personal Message

# %%
x = "Shohan"
print("Hello", x,", would you like to learn some Python today?")
# Out:
# Hello Shohan , would you like to learn some Python today?

# %% [markdown]
# 2-4. Name Cases

# %%
#Upper case
x = "ShOhaN"
x.upper()
#Lower case
x.lower()
#Title case
x.title()
# Out:
# 'Shohan'

# %% [markdown]
# 2-5.Famous Quote:

# %%
print("""Yeasir Arafat Once said, 'Don’t repeat your today on tomorrow. \nIt will get you into Rat-Race.'""")
# Out:
# Y.A.Shohan Once said, 'Don’t repeat your today on tomorrow.
# It will get you into Rat-Race.'

# %% [markdown]
# 2-6. Famous Quote 2:

# %%
famous_person = "Yeasir Arafat"
message = famous_person + " Once said, 'Don’t repeat your today on tomorrow. \nIt will get you into Rat-Race.'"
print(message)
# Out:
# Yeasir Arafat Once said, 'Don’t repeat your today on tomorrow.
# It will get you into Rat-Race.'

# %% [markdown]
# 2-7. Stripping Names:

# %%
name = "   \t\nYeasir Arafat\t\n   "
print(name)

print(name.strip())
print(name.lstrip())
print(name.rstrip())
# Out:
#
# Yeasir Arafat
#
# Yeasir Arafat
# Yeasir Arafat
#
#
# Yeasir Arafat

# %% [markdown]
# 2-8. Number Eight:

# %%
print(6+2)
print(12-4)
print(4*2)
print(16//2)
# Out:
# 8
# 8
# 8
# 8

# %% [markdown]
# 2-9. Favorite Number:

# %%
fav_num = 24
print(str(fav_num) + " is my favorite number!")
# Out:
# 24 is my favorite number!

# %% [markdown]
# 2-10. Adding Comments

# %%
"""Change value of variable x.
Here i was change the value x in this code"""

x = "This is a first Assingment"
print(x)

x = "This is a change value of variable"
print(x)

"""In this section i applyed upper case, lower case and title case"""
#Upper case
x = "ShOhaN"
x.upper()
#Lower case
x.lower()
#Title case
x.title()
# Out:
# This is a first Assingment
# This is a change value of variable
# 'Shohan'
