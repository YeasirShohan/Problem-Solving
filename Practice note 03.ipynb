# %% [markdown]
# # **Assignment: 04**
#
# ##**Topic: Python dictionary**
#
# **Source: W3School Python Tutorial(Dictionary)**
#
# **Submitted by: Yeasir Arafat Shohan**
#
# **Discord ID: 0781**

# %% [markdown]
# ##**Dictionary Example**

# %% [markdown]
# **Create and print a dictionary**

# %%
newdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(newdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# **Print the "brand" value of the dictionary**

# %%
newdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(newdict["brand"])
# Out:
# Ford

# %% [markdown]
# **Duplicate values will overwrite existing values**

# %%
#Dictionaries cannot have two items with the same key
newdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(newdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %% [markdown]
# **Print the number of items in the dictionary**

# %%
#To determine how many items a dictionary has, use the len() function
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(len(thisdict))
# Out:
# 3

# %% [markdown]
# **String, int, boolean, and list data types**

# %%
#The values in dictionary items can be of any data type
dict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}
print(dict)
# Out:
# {'brand': 'Ford', 'electric': False, 'year': 1964, 'colors': ['red', 'white', 'blue']}

# %% [markdown]
# **Print the data type of a dictionary**

# %%
#From Python's perspective, dictionaries are defined as objects with the data type 'dict'
dict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(type(dict))

# %% [markdown]
# **Using the dict() method to make a dictionary**

# %%
#It is also possible to use the dict() constructor to make a dictionary
newdic = dict(name = "John", age = 36, country = "Norway")

print(newdict)

# %% [markdown]
# **Get the value of the "model" key**

# %%
#You can access the items of a dictionary by referring to its key name, inside square brackets
newdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = newdict["model"]
print(x)
# Out:
# Mustang

# %% [markdown]
# **Get the value of the "model" key**

# %%
#There is also a method called get() that will give you the same result
newdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = newdict.get("model")
print(x)
# Out:
# Mustang

# %% [markdown]
# **The keys() method will return a list of all the keys in the dictionary**

# %%
#Get a list of the keys
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = thisdict.keys()

print(x)
# Out:
# dict_keys(['brand', 'model', 'year'])

# %% [markdown]
# **Add a new item to the original dictionary, and see that the keys list gets updated as well**

# %%
'''The list of the keys is a view of the dictionary, 
meaning that any changes done to the dictionary 
will be reflected in the keys list'''

car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.keys()

print(x) #before the change

car["color"] = "white"

print(x) #after the change
# Out:
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])

# %% [markdown]
# **Change the "year" to 2018**

# %%
# You can change the value of a specific item by referring to its key name
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["year"] = 2018
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2018}

# %% [markdown]
# **Update the "year" of the car by using the update() method**

# %%
'''The update() method will update the dictionary with the items from the given argument.
The argument must be a dictionary, or an iterable object with key:value pairs'''

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"year": 2020})
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %% [markdown]
# **Adding an item to the dictionary is done by using a new index key and assigning a value to it**

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["color"] = "red"
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %% [markdown]
# **Add a color item to the dictionary by using the update() method**

# %%
'''The update() method will update the dictionary with the items from a given argument. 
If the item does not exist, the item will be added.
The argument must be a dictionary, or an iterable object with key:value pairs'''

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"color": "red"})

# %% [markdown]
# **The pop() method removes the item with the specified key name**

# %%
# There are several methods to remove items from a dictionary

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %% [markdown]
# **The popitem() method removes the last inserted item (in versions before 3.7, a random item is removed instead)**

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %% [markdown]
# **The del keyword removes the item with the specified key name**

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict["model"]
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %% [markdown]
# **The del keyword can also delete the dictionary completely**

# %%
#error code
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict
print(thisdict) #this will cause an error because "thisdict" no longer exists.

# %% [markdown]
# **The clear() method empties the dictionary**

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.clear()
print(thisdict)
# Out:
# {}

# %% [markdown]
# **Make a copy of a dictionary with the copy() method**

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict.copy()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# **Make a copy of a dictionary with the dict() function**

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = dict(thisdict)
print(mydict)

# %% [markdown]
# **Create a dictionary that contain three dictionaries**

# %%
# A dictionary can contain dictionaries, this is called nested dictionaries
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(myfamily)
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}

# %% [markdown]
# **Create three dictionaries, then create one dictionary that will contain the other three dictionaries**

# %%
# if you want to add three dictionaries into a new dictionary

child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}

print(myfamily)
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}

# %% [markdown]
# **Print the name of child 2**

# %%
# To access items from a nested dictionary, you use the name of the dictionaries, starting with the outer dictionary
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

print(myfamily["child2"]["name"])
# Out:
# Tobias

# %% [markdown]
# ##**Dictionary Exercise**

# %% [markdown]
# **01: Use the get method to print the value of the "model" key of the car**

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(car.get("model"))
# Out:
# Mustang

# %% [markdown]
# **02: Change the "year" value from 1964 to 2020**

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
car["year"] = 2020
print(car)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %% [markdown]
# **03: Add the key/value pair "color" : "red" to the car dictionary**

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
car["color"] = "red"
print(car)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %% [markdown]
# **04: Use the pop method to remove "model" from the car dictionary**

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
car.pop("model")
print(car)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %% [markdown]
# **05: Use the clear method to empty the car dictionary**

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
car.clear()
print(car)
# Out:
# {}
